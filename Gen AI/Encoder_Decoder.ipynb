# %% [markdown]
# **ENCODER-DECODER**

# %% [markdown]
# **Limitation of RNN??**
#
# 1- Vanishing Gradient -> RNN model is not able to remember the long term information

# %% [markdown]
# **TO SOLVE THE PROBLEM / LIMITATION OF RNN??**
#
# - LSTM (Long -Short term Memory) -> RNN + Gate Mechanism

# %% [markdown]
# **SEQUENCE - TO- SEQUENCE MODELS**
#
# - It is a type of neural network used when both the input and output are sequences(ordered data)
#
# - Take a sequence as input
#
# - process it
#
# - Generates another sequence as output

# %%
# Input and Output sequences may have different length and normal RNN cannot handle this easily

# %%
# SPLIT MODEL INTO TWO PARTS ??
# ENCODER
# DECODER

# %% [markdown]
# **Encoder-Decoder is a neural network architecture where one network reads the input sentence and another network generates the output sentence.**

# %%
# ENCODER -> read the entire input sentence

# %%
import tensorflow as tf
import numpy as np
from collections import Counter
import random

# %%
data = [ ("i am happy","मैं खुश हूँ"),
         ("You are sad","आप दुखी हैं"),
         ("she is tired", "वह थक गया है"),
         ("we are hungry","हम भूखें है"),
         ("they are busy","वे व्यस्त हैं"),
         ("i am cold","मुझे ठंड लग रही है"),
         ("you are late","तुम देरी से आए हो"),
         ("she is happy", "वह खुश है"),
         ("we are ready","हम तैयार हैं")]

# %%
data[0]
# Out:
# ('i am happy', 'मैं खुश हूँ')

# %%
data[0][0]
# Out:
# 'i am happy'

# %%
# english sentence -> INPUT
# hindi sentence -> OUTPUT

# %%
# SEPARETE ENGLISH SEQUENCE AND HINDI SEQUENCE
eng_sentence = []
hin_sentence=[]

for pair in data:
  eng_sentence.append(pair[0])
  hin_sentence.append(pair[1])

# %%
eng_sentence
# Out:
# ['i am happy',
#  'You are sad',
#  'she is tired',
#  'we are hungry',
#  'they are busy',
#  'i am cold',
#  'you are late',
#  'she is happy',
#  'we are ready']

# %%
hin_sentence
# Out:
# ['मैं खुश हूँ',
#  'आप दुखी हैं',
#  'वह थक गया है',
#  'हम भूखें है',
#  'वे व्यस्त हैं',
#  'मुझे ठंड लग रही है',
#  'तुम देरी से आए हो',
#  'वह खुश है',
#  'हम तैयार हैं']

# %%
# TOKENIZATION (split the text into tokens) 
eng_tokens = []
hin_tokens = []

for i in eng_sentence:
    eng_tokens.append(i.split())

for i in hin_sentence:
    hin_tokens.append(i.split())

# %%
eng_tokens
# Out:
# [['i', 'am', 'happy'],
#  ['You', 'are', 'sad'],
#  ['she', 'is', 'tired'],
#  ['we', 'are', 'hungry'],
#  ['they', 'are', 'busy'],
#  ['i', 'am', 'cold'],
#  ['you', 'are', 'late'],
#  ['she', 'is', 'happy'],
#  ['we', 'are', 'ready']]

# %%
# BECAUSE MODEL CAN'T UNDERSTAND FULL SENTENCES , IT NEEDS WORD-BY -WORD INPUT
# SO WE HAVE PERFORMED TOKENIZATION

# %% [markdown]
# **VOCAB -** list all the unique words(tokens)

# %%
eng_vocab=[]
hin_vocab =[]

for i in eng_tokens:
  for j in i:
    eng_vocab.append(j)

for i in hin_tokens:
  for j in i:
    hin_vocab.append(j)

# %%
eng_vocab
# Out:
# ['i',
#  'am',
#  'happy',
#  'You',
#  'are',
#  'sad',
#  'she',
#  'is',
#  'tired',
#  'we',
#  'are',
#  'hungry',
#  'they',
#  'are',
#  'busy',
#  'i',
#  'am',
#  'cold',
#  'you',
#  'are',
#  'late',
#  'she',
#  'is',
#  'happy',
#  'we',
#  'are',
#  'ready']

# %%
# SO THERE ARE MULTIPLE TOKENS WHICH ARE REPEATING
# NOW WE NEED TO FIND UNIQUE TOKENS

# %%
eng_vocab = list(set(eng_vocab))
hin_vocab = list(set(hin_vocab))

# %%
eng_vocab
# Out:
# ['ready',
#  'are',
#  'cold',
#  'you',
#  'late',
#  'she',
#  'hungry',
#  'happy',
#  'they',
#  'i',
#  'busy',
#  'sad',
#  'am',
#  'is',
#  'tired',
#  'we',
#  'You']

# %% [markdown]
# **convert words into numbers**

# %%
eng_word2index = {}
hin_word2index = {}

# english word to index
for i , word in enumerate(eng_vocab):
  eng_word2index[word] =  i +1

for i , word in enumerate(hin_vocab):
  hin_word2index[word] =  i +1

# %%
# WHY I+1?
# Because 0 is reserved for padding later

# %%
eng_word2index
# Out:
# {'ready': 1,
#  'are': 2,
#  'cold': 3,
#  'you': 4,
#  'late': 5,
#  'she': 6,
#  'hungry': 7,
#  'happy': 8,
#  'they': 9,
#  'i': 10,
#  'busy': 11,
#  'sad': 12,
#  'am': 13,
#  'is': 14,
#  'tired': 15,
#  'we': 16,
#  'You': 17}

# %%
# list of numbers for each sentence

# %%
eng_sequences =[]
hin_sequences = []

# English
for sent in eng_tokens:
  temp=[]
  for word in sent:
    temp.append(eng_word2index[word])
  eng_sequences.append(temp)

# Hindi
for sent in hin_tokens:
  temp=[]
  for word in sent:
    temp.append(hin_word2index[word])
  hin_sequences.append(temp)

# %%
hin_sequences
# Out:
# [[12, 8, 23],
#  [9, 20, 10],
#  [17, 5, 3, 24],
#  [13, 16, 24],
#  [21, 15, 10],
#  [14, 6, 4, 22, 24],
#  [1, 11, 19, 18, 7],
#  [17, 8, 24],
#  [13, 2, 10]]

# %%
# Add <start> and <end> token

# %%
# Add token to dictionary
hin_word2index['<start>'] = len(hin_word2index)+1
hin_word2index['<end>'] = len(hin_word2index)+1

# %%
new_hin_sequences = []
for seq in hin_sequences:
  start = hin_word2index['<start>']
  end = hin_word2index['<end>']

  new_seq = [start] + seq + [end]
  new_hin_sequences.append(new_seq)

hin_sequences = new_hin_sequences

# %%
new_hin_sequences
# Out:
# [[25, 12, 8, 23, 26],
#  [25, 9, 20, 10, 26],
#  [25, 17, 5, 3, 24, 26],
#  [25, 13, 16, 24, 26],
#  [25, 21, 15, 10, 26],
#  [25, 14, 6, 4, 22, 24, 26],
#  [25, 1, 11, 19, 18, 7, 26],
#  [25, 17, 8, 24, 26],
#  [25, 13, 2, 10, 26]]

# %%
# OUR SEQUENCE HAS DIFFERENT LENGTH , SO WE WILL PERFORM HERE PADDING
# PADDING -> arranging/matching all the sequence into the same length

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

eng_sequences = pad_sequences(eng_sequences,padding='post')
hin_sequences = pad_sequences(hin_sequences,padding='post')

# %%
hin_sequences
# Out:
# array([[25, 12,  8, 23, 26,  0,  0],
#        [25,  9, 20, 10, 26,  0,  0],
#        [25, 17,  5,  3, 24, 26,  0],
#        [25, 13, 16, 24, 26,  0,  0],
#        [25, 21, 15, 10, 26,  0,  0],
#        [25, 14,  6,  4, 22, 24, 26],
#        [25,  1, 11, 19, 18,  7, 26],
#        [25, 17,  8, 24, 26,  0,  0],
#        [25, 13,  2, 10, 26,  0,  0]], dtype=int32)

# %% [markdown]
# **MODEL BUILDING**

# %%
# define sizes
eng_vocab_size = len(eng_word2index)+1
hin_vocab_size = len(hin_word2index)+1

embedding_dim = 64
units = 128

# %%
# encoder input
encoder_inputs = tf.keras.Input(shape=(None,))
# ANY LENGTH OF INPUT IS ALLOWED

# %%
encoder_embedding = tf.keras.layers.Embedding(eng_vocab_size,embedding_dim)(encoder_inputs)

# %%
encoder_lstm = tf.keras.layers.LSTM(units, return_state=True)
encoder_output, state_h, state_c = encoder_lstm(encoder_embedding)

# %%
decoder_inputs = tf.keras.Input(shape=(None,))
decoder_inputs

decoder_embedding = tf.keras.layers.Embedding(hin_vocab_size, embedding_dim)(decoder_inputs)

decoder_embedding
decoder_lstm = tf.keras.layers.LSTM(units, return_sequences=True, return_state=True)

decoder_outputs, _, _ = decoder_lstm(
    decoder_embedding, initial_state=[state_h, state_c]
)

decoder_dense = tf.keras.layers.Dense(hin_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = tf.keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# %%
decoder_input_data = hin_sequences[:, :-1]
decoder_output_data = hin_sequences[:, 1:]

model.fit(
    [eng_sequences, decoder_input_data],
    decoder_output_data,
    epochs=200
)
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - loss: 3.2954
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 3.2867
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 3.2777
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 3.2681
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 3.2575
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 3.2456
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 3.2320
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 3.2160
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 3.1970
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 3.1744
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 3.1470
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 3.1136
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 3.0725
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 3.0218
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 2.9588
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 2.8809
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 2.7860
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 2.6745
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 2.5541
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.4443
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2.3737
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 2.3585
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 2.3768
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2.3870
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 2.3725
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 2.3398
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 2.3024
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 2.2712
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 2.2488
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 2.2313
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 2.2155
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 2.1999
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 2.1840
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 2.1671
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 2.1489
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 2.1293
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 2.1093
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 2.0899
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 2.0727
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2.0583
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 2.0466
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 2.0364
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - loss: 2.0260
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 2.0135
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 1.9984
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.9810
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 1.9626
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 1.9449
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 1.9289
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.9147
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.9019
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 1.8894
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.8766
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.8629
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - loss: 1.8487
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 1.8339
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.8188
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.8030
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.7863
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.7688
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 1.7510
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.7333
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1.7159
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.6984
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.6799
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 1.6599
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.6385
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.6163
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.5935
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.5703
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.5463
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.5214
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 1.4959
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.4702
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.4441
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1.4178
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.3914
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.3653
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.3397
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.3143
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 1.2889
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 1.2639
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 1.2393
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 1.2149
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.1905
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 1.1662
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.1422
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 1.1184
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 1.0945
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 1.0705
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1.0465
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.0221
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.9977
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.9734
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.9492
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.9253
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.9013
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.8772
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.8529
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.8284
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.8041
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.7802
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.7565
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.7331
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.7096
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.6863
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.6633
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.6408
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.6187
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.5971
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.5761
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.5556
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.5358
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.5166
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.4979
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4798
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4622
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.4451
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.4284
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.4123
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.3965
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.3812
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.3664
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3521
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.3383
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.3252
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.3125
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3005
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2889
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.2779
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2673
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.2572
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.2474
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.2379
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2288
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2200
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.2116
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.2036
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.1958
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1885
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1814
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.1747
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1682
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1619
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.1559
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1502
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 0.1446
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.1393
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.1341
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1292
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.1245
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1199
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.1156
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.1114
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1074
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.1035
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0999
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0964
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0930
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0898
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0867
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0838
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0809
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0781
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0754
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0729
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0704
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0680
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0658
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0636
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0616
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0596
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0578
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0560
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0543
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0526
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0511
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0496
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0481
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0467
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0454
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0441
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0428
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0416
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0405
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0394
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0384
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0373
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0364
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0354
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0345
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0337
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.0328
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.0320
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0313
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0305
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0298
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0291
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0284
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0278

# %%
# TESTING

# %%
def translate_step_by_step(sentence):
    print("\nInput Sentence:", sentence)

    # Step 1: Convert to numbers
    test_seq = [eng_word2index[word] for word in sentence.split()]
    test_seq = np.array(test_seq).reshape(1, -1)

    print("Converted to numbers:", test_seq)

    # Step 2: Start with <start>
    start_token = hin_word2index['<start>']
    end_token = hin_word2index['<end>']

    decoder_input = np.array([[start_token]])

    print("Starting decoder with <start>\n")

    output = []

    for step in range(10):
        pred = model.predict([test_seq, decoder_input])

        next_word = np.argmax(pred[0, -1, :])

        # convert number → word
        idx2word = {v:k for k,v in hin_word2index.items()}
        word = idx2word.get(next_word, "?")

        print(f"Step {step+1}: Predicted word → {word}")

        if next_word == end_token:
            print("Reached <end> token. STOP.")
            break

        output.append(word)

        # add to decoder input
        decoder_input = np.append(decoder_input, [[next_word]], axis=1)

    print("\nFinal Translation:", " ".join(output))

# %%
translate_step_by_step('i am happy')
# Out:
# Input Sentence: i am happy
# Converted to numbers: [[10 13  8]]
# Starting decoder with <start>
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Step 1: Predicted word → मैं
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Step 2: Predicted word → खुश
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Step 3: Predicted word → हूँ
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Step 4: Predicted word → <end>
# Reached <end> token. STOP.
#
# Final Translation: मैं खुश हूँ

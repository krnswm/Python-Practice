# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./cars.csv')
df
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %% [markdown]
# 1. Create scatter plots for the following data, make sure all the plots appear in the same
# plane with x-labels and y-labels evenly spaced.
#
# a. Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg,
# hp-time-to-60) with respect to each brand

# %%
fig = plt.subplots(2,2, figsize = (20,10))

#mpg-hp
plt.subplot(2,2,1)
sns.scatterplot(x = df['mpg'], y =df['hp'],data = df, hue =df['brand'])
plt.xlabel("mpg")
plt.ylabel("hp")
plt.title("mpg vs hp")

#mpg-weight
plt.subplot(2,2,2)
sns.scatterplot(x = df['mpg'], y = df['weightlbs'], data = df, hue = df['brand'])
plt.xlabel('mpg')
plt.ylabel('weight')
plt.title('mpg vs weight')

# hp-mpg
plt.subplot(2,2,3)
sns.scatterplot(x = df['hp'], y =df['mpg'],data = df, hue =df['brand'])
plt.xlabel("hp")
plt.ylabel("mpg")
plt.title(" hp vsmpg")

#hp-time-to-60

plt.subplot(2,2,4)
sns.scatterplot(x = df['hp'], y =df['time-to-60'],data = df, hue =df['brand'])
plt.xlabel("hp")
plt.ylabel("time-to-60")
plt.title(" hp vs time-to-60")

plt.show()

# %% [markdown]
# 2. Create a histogram for the following:
#
# a. Create histograms for hp, mpg, time-to-60, weight lbs, cubic inches, year, with
# respect to brand.

# %%
fig=plt.subplots(3,2,figsize=(20,20))

plt.subplot(3,2,1)
sns.histplot(data=df,x=df['hp'],hue=df['brand'])
plt.xlabel('HP')
plt.ylabel('Frequency')
plt.title('Histogram of HP')

plt.subplot(3,2,2)
sns.histplot(data=df,x=df['mpg'],hue=df['brand'])
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.title('Histogram of MPG')

plt.subplot(3,2,3)
sns.histplot(data=df,x=df['time-to-60'],hue=df['brand'])
plt.xlabel('Time-to-60')
plt.ylabel('Frequency')
plt.title('Histogram of Time')

plt.subplot(3,2,4)
sns.histplot(data=df,x=df['weightlbs'],hue=df['brand'])
plt.xlabel('WeightLBS')
plt.ylabel('Frequency')
plt.title('Histogram of WeightLBS')

plt.subplot(3,2,5)
sns.histplot(data=df,x=df['cubicinches'],hue=df['brand'])
plt.xlabel('Cubic Inches')
plt.ylabel('Frequency')
plt.title('Histogram of Cubic Inches')

plt.subplot(3,2,6)
sns.histplot(data=df,x=df['year'],hue=df['brand'])
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.title('Histogram of Year')

plt.show()

# %% [markdown]
# 3. Create line plots for the following:
# a. Line plot between hp-mpg, hp-(time-to-60), mpg-(time-to-60), hp-weight lbs,
# mpg-weight lbs, cubic inches-weight lbs.

# %%
fig=plt.subplots(2,3,figsize=(20,20))
plt.subplot(2,3,1)
sns.lineplot(data=df,x=df['hp'],y=df['mpg'])
plt.xlabel('HP')
plt.ylabel('MPG')
plt.title('Line Plot b/w HP and MPG')

plt.subplot(2,3,1)
sns.lineplot(data=df,x=df['hp'],y=df['mpg'])
plt.xlabel('HP')
plt.ylabel('MPG')
plt.title('Line Plot b/w HP and MPG')

plt.subplot(2,3,2)
sns.lineplot(data=df,x=df['hp'],y=df['time-to-60'])
plt.xlabel('HP')
plt.ylabel('Time-to-60 ')
plt.title('Line Plot b/w HP and Time In 60')

plt.subplot(2,3,3)
sns.lineplot(data=df,x=df['mpg'],y=df['time-to-60'])
plt.xlabel('MPG')
plt.ylabel('Time-to-60')
plt.title('Line Plot b/w MPG and Time-to-60')

plt.subplot(2,3,4)
sns.lineplot(data=df,x=df['hp'],y=df['weightlbs'])
plt.xlabel('HP')
plt.ylabel('Weightlbs')
plt.title('Line Plot b/w HP and WeightLBS')

plt.subplot(2,3,5)
sns.lineplot(data=df,x=df['mpg'],y=df['weightlbs'])
plt.xlabel('MPG')
plt.ylabel('Weigthlbs')
plt.title('Line Plot b/w MPG and Weightlbs')

plt.subplot(2,3,6)
sns.lineplot(data=df,x=df['cubicinches'],y=df['weightlbs'])
plt.xlabel('cubicinches')
plt.ylabel('Weigthlbs')
plt.title('cubicinches and Weightlbs')
# Out:
# Text(0.5, 1.0, 'cubicinches and Weightlbs')

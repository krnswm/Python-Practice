# %%
import matplotlib.pyplot as plt
import pandas as pd

df1 = pd.read_csv('../Pandas/Auto.csv')
df1.head()
# Out:
#     mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 0  18.0        8.0         307.0         130    3504          12.0    70
# 1  15.0        8.0         350.0         165    3693          11.5    70
# 2   NaN        8.0         318.0         150    3436          11.0    70
# 3   NaN        8.0           NaN         150    3433          12.0    70
# 4   NaN        8.0           NaN         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Advanced visualisation

# %%
import seaborn as sns

# %%
plt.scatter(df1['mpg'], df1['weight'])

# %%
plt.scatter(df1['acceleration'], df1['displacement'])

# %%
# Correlation : Calculate relation between two continuous columns

df1[['mpg','weight','acceleration','displacement']].corr()
# Out:
#                    mpg    weight  acceleration  displacement
# mpg           1.000000 -0.830273      0.410981     -0.803730
# weight       -0.830273  1.000000     -0.419502      0.933743
# acceleration  0.410981 -0.419502      1.000000     -0.520372
# displacement -0.803730  0.933743     -0.520372      1.000000

# %%
# Using Correlation we are identifying is the relation between columns negative or positive

# %%
sns.heatmap(df1[['mpg','weight','acceleration','displacement']].corr())
# Out:
# <Axes: >

# %%
sns.heatmap(df1[['mpg','weight','acceleration','displacement']].corr(), cmap = 'Paired')
# cmap is the different shades of color palette that we can use
# Out:
# <Axes: >

# %%
sns.heatmap(df1[['mpg','weight','acceleration','displacement']].corr(), cmap ='Blues', annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df1[['mpg','acceleration','weight']])

# %%
sns.countplot(x = 'origin', data = df1, hue = 'cylinders')
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
df1['cylinders'][df1['origin'] == 2].value_counts()
# Out:
# cylinders
# 4.0    63
# 6.0     4
# 5.0     3
# Name: count, dtype: int64

# %%
df1[df1['origin'] == 2]
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 19   26.0        4.0          97.0          46    1835          20.5    70
# 20   25.0        4.0         110.0          87    2672          17.5    70
# 21   24.0        4.0         107.0          90    2430          14.5    70
# 22   25.0        4.0         104.0          95    2375          17.5    70
# 23   26.0        4.0         121.0         113    2234          12.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 354  34.5        4.0         100.0           ?    2320          15.8    81
# 359  28.1        4.0         141.0          80    3230          20.4    81
# 360  30.7        6.0         145.0          76    3160          19.6    81
# 374  36.0        4.0         105.0          74    1980          15.3    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
#
#      origin                          name
# ...

# %%
cond1 = df1['origin'] == 2
df1[cond1]
# Out:
#       mpg  cylinders  displacement Horse Power  weight  acceleration  year  \
# 19   26.0        4.0          97.0          46    1835          20.5    70
# 20   25.0        4.0         110.0          87    2672          17.5    70
# 21   24.0        4.0         107.0          90    2430          14.5    70
# 22   25.0        4.0         104.0          95    2375          17.5    70
# 23   26.0        4.0         121.0         113    2234          12.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 354  34.5        4.0         100.0           ?    2320          15.8    81
# 359  28.1        4.0         141.0          80    3230          20.4    81
# 360  30.7        6.0         145.0          76    3160          19.6    81
# 374  36.0        4.0         105.0          74    1980          15.3    82
# 393  44.0        4.0          97.0          52    2130          24.6    82
#
#      origin                          name
# ...

# %%
output =  df1[df1['origin'] == 2]
output['cylinders'].value_counts()
# Out:
# cylinders
# 4.0    63
# 6.0     4
# 5.0     3
# Name: count, dtype: int64

# %%
df1[df1['origin'] == 2]['cylinders'].value_counts()
# 1. extract the rows where origin column is = 2 
# 2. from the above data extract only cylinders column 
# 3. on that extracted cylinders column apply value_counts() function
# Out:
# cylinders
# 4.0    63
# 6.0     4
# 5.0     3
# Name: count, dtype: int64

# %%
sns.countplot(x = 'origin', data = df1,hue = 'cylinders')
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
df1[df1['origin'] == 1]['cylinders'].value_counts()
# Out:
# cylinders
# 8.0    100
# 6.0     74
# 4.0     71
# Name: count, dtype: int64

# %%
df1['cylinders'][df1['origin'] == 1].value_counts()
# Out:
# cylinders
# 8.0    100
# 6.0     74
# 4.0     71
# Name: count, dtype: int64

# %%
df1.groupby(['origin','cylinders']).size().reset_index()
# Out:
#    origin  cylinders    0
# 0       1        4.0   71
# 1       1        6.0   74
# 2       1        8.0  100
# 3       2        4.0   63
# 4       2        5.0    3
# 5       2        6.0    4
# 6       3        3.0    4
# 7       3        4.0   69
# 8       3        6.0    6
